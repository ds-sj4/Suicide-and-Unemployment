# %%
#Importing packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Reading in the csv file
df = pd.read_csv('SuicideAndUnemployment.csv', encoding='UTF-8')

# %%
df.head()
# Out:
#                                        Series Name     Series Code  \
# 0  Suicide mortality rate (per 100,000 population)  SH.STA.SUIC.P5
# 1     Unemployment, total (% of total labor force)  SL.UEM.TOTL.ZS
# 2  Suicide mortality rate (per 100,000 population)  SH.STA.SUIC.P5
# 3     Unemployment, total (% of total labor force)  SL.UEM.TOTL.ZS
# 4  Suicide mortality rate (per 100,000 population)  SH.STA.SUIC.P5
#
#                   Country Name Country Code  2002 [YR2002]  2003 [YR2003]  \
# 0  Africa Eastern and Southern          AFE      10.373434      10.229879
# 1  Africa Eastern and Southern          AFE       7.959582       7.787965
# 2   Africa Western and Central          AFW       6.611609       6.599238
# 3   Africa Western and Central          AFW       4.781385       4.751168
# 4                   Arab World          ARB       4.546875       4.496886
#
#    2004 [YR2004]  2005 [YR2005]  2006 [YR2006]  2007 [YR2007]  ...  \
# ...

# %%
#Deleting unnessecary columns
del df["Series Code"]
del df["Country Code"]

# %%
#Filtering data frames by different regions
df_1 = df[df["Country Name"] == "Africa Eastern and Southern"] 
df_2 = df[df["Country Name"] == "Africa Western and Central"]
df_3 = df[df["Country Name"] == "Arab World"]
df_4 = df[df["Country Name"] == "Caribbean small states"]
df_5 = df[df["Country Name"] == "Central Europe and the Baltics"]
df_6 = df[df["Country Name"] == "East Asia & Pacific"]
df_7 = df[df["Country Name"] == "Euro area"]
df_8 = df[df["Country Name"] == "Europe & Central Asia"]
df_9 = df[df["Country Name"] == "European Union"]
df_10 = df[df["Country Name"] == "Latin America & Caribbean"]
df_11 = df[df["Country Name"] == "Middle East & North Africa"]
df_12 = df[df["Country Name"] == "Pacific island small states"]
df_13 = df[df["Country Name"] == "Sub-Saharan Africa"]

# %%
#Deleting Regions of the world
del df_1["Country Name"]
del df_2["Country Name"]
del df_3["Country Name"]
del df_4["Country Name"]
del df_5["Country Name"]
del df_6["Country Name"]
del df_7["Country Name"]
del df_8["Country Name"]
del df_9["Country Name"]
del df_10["Country Name"]
del df_11["Country Name"]
del df_12["Country Name"]
del df_13["Country Name"]

# %%
#Wider to Longer
df_1t = pd.melt(df_1, id_vars=['Series Name'], value_vars=['2002 [YR2002]', '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]', '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]', '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]', '2019 [YR2019]'])
df_2t = pd.melt(df_2, id_vars=['Series Name'], value_vars=['2002 [YR2002]', '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]', '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]', '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]', '2019 [YR2019]'])
df_3t = pd.melt(df_3, id_vars=['Series Name'], value_vars=['2002 [YR2002]', '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]', '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]', '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]', '2019 [YR2019]'])
df_4t = pd.melt(df_4, id_vars=['Series Name'], value_vars=['2002 [YR2002]', '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]', '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]', '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]', '2019 [YR2019]'])
df_5t = pd.melt(df_5, id_vars=['Series Name'], value_vars=['2002 [YR2002]', '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]', '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]', '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]', '2019 [YR2019]'])
df_6t = pd.melt(df_6, id_vars=['Series Name'], value_vars=['2002 [YR2002]', '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]', '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]', '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]', '2019 [YR2019]'])
df_7t = pd.melt(df_7, id_vars=['Series Name'], value_vars=['2002 [YR2002]', '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]', '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]', '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]', '2019 [YR2019]'])
df_8t = pd.melt(df_8, id_vars=['Series Name'], value_vars=['2002 [YR2002]', '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]', '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]', '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]', '2019 [YR2019]'])
df_9t = pd.melt(df_9, id_vars=['Series Name'], value_vars=['2002 [YR2002]', '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]', '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]', '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]', '2019 [YR2019]'])
df_10t = pd.melt(df_10, id_vars=['Series Name'], value_vars=['2002 [YR2002]', '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]', '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]', '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]', '2019 [YR2019]'])
df_11t = pd.melt(df_11, id_vars=['Series Name'], value_vars=['2002 [YR2002]', '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]', '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]', '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]', '2019 [YR2019]'])
df_12t = pd.melt(df_12, id_vars=['Series Name'], value_vars=['2002 [YR2002]', '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]', '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]', '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]', '2019 [YR2019]'])
df_13t = pd.melt(df_13, id_vars=['Series Name'], value_vars=['2002 [YR2002]', '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]', '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]', '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]', '2019 [YR2019]'])

# %%
#Longer to Wider
df_aes = pd.pivot(df_1t, index='variable', columns='Series Name', values='value')
df_aws = pd.pivot(df_2t, index='variable', columns='Series Name', values='value')
df_aw = pd.pivot(df_3t, index='variable', columns='Series Name', values='value')
df_css = pd.pivot(df_4t, index='variable', columns='Series Name', values='value')
df_ceb = pd.pivot(df_5t, index='variable', columns='Series Name', values='value')
df_eap = pd.pivot(df_6t, index='variable', columns='Series Name', values='value')
df_ea = pd.pivot(df_7t, index='variable', columns='Series Name', values='value')
df_eca = pd.pivot(df_8t, index='variable', columns='Series Name', values='value')
df_eu = pd.pivot(df_9t, index='variable', columns='Series Name', values='value')
df_lac = pd.pivot(df_10t, index='variable', columns='Series Name', values='value')
df_mena = pd.pivot(df_11t, index='variable', columns='Series Name', values='value')
df_pss = pd.pivot(df_12t, index='variable', columns='Series Name', values='value')
df_ssa = pd.pivot(df_13t, index='variable', columns='Series Name', values='value')

# %%
#Plotting Regression Lines
sns.lmplot("Unemployment, total (% of total labor force)", "Suicide mortality rate (per 100,000 population)", df_aes).set(title='Africa Eastern and Southern')
sns.lmplot("Unemployment, total (% of total labor force)", "Suicide mortality rate (per 100,000 population)", df_aws).set(title='Africa Western and Central')
sns.lmplot("Unemployment, total (% of total labor force)", "Suicide mortality rate (per 100,000 population)", df_aw).set(title='Arab World')
sns.lmplot("Unemployment, total (% of total labor force)", "Suicide mortality rate (per 100,000 population)", df_css).set(title='Caribbean small states')
sns.lmplot("Unemployment, total (% of total labor force)", "Suicide mortality rate (per 100,000 population)", df_ceb).set(title='Central Europe and the Baltics')
sns.lmplot("Unemployment, total (% of total labor force)", "Suicide mortality rate (per 100,000 population)", df_eap).set(title='East Asia & Pacific')
sns.lmplot("Unemployment, total (% of total labor force)", "Suicide mortality rate (per 100,000 population)", df_ea).set(title='Euro area')
sns.lmplot("Unemployment, total (% of total labor force)", "Suicide mortality rate (per 100,000 population)", df_eca).set(title='Europe & Central Asia')
sns.lmplot("Unemployment, total (% of total labor force)", "Suicide mortality rate (per 100,000 population)", df_eu).set(title='European Union')
sns.lmplot("Unemployment, total (% of total labor force)", "Suicide mortality rate (per 100,000 population)", df_lac).set(title='Latin America & Caribbean')
sns.lmplot("Unemployment, total (% of total labor force)", "Suicide mortality rate (per 100,000 population)", df_mena).set(title='Middle East & North Africa')
sns.lmplot("Unemployment, total (% of total labor force)", "Suicide mortality rate (per 100,000 population)", df_pss).set(title='Pacific island small states')
sns.lmplot("Unemployment, total (% of total labor force)", "Suicide mortality rate (per 100,000 population)", df_ssa).set(title='Sub-Saharan Africa')
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\sarah\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\sarah\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ...

# %%
#Africa Eastern and Southern Regression
from sklearn.linear_model import LinearRegression

est = LinearRegression(fit_intercept = True)

x = df_aes[['Unemployment, total (% of total labor force)']]
y = df_aes[['Suicide mortality rate (per 100,000 population)']]

est.fit(x, y)

print("Coefficients:", est.coef_)
print ("Intercept:", est.intercept_)
# Out:
# Coefficients: [[0.89526842]]
# Intercept: [3.0779002]

# %%
#Africa Eastern and Southern R Square
from sklearn import metrics

x = df_aes[['Unemployment, total (% of total labor force)']]
y = df_aes[['Suicide mortality rate (per 100,000 population)']]
model = LinearRegression()
model.fit(x, y)
y_hat = model.predict(x)
print ("R^2:", metrics.r2_score(y_hat, y))
# Out:
# R^2: -1.503821927736214

# %%
#Africa Western and Central Regression
from sklearn.linear_model import LinearRegression

est = LinearRegression(fit_intercept = True)

x = df_aws[['Unemployment, total (% of total labor force)']]
y = df_aws[['Suicide mortality rate (per 100,000 population)']]

est.fit(x, y)

print("Coefficients:", est.coef_)
print ("Intercept:", est.intercept_)
# Out:
# Coefficients: [[-0.63463315]]
# Intercept: [9.31923378]

# %%
#Africa Western and Central R Square
from sklearn import metrics

x = df_aws[['Unemployment, total (% of total labor force)']]
y = df_aws[['Suicide mortality rate (per 100,000 population)']]
model = LinearRegression()
model.fit(x, y)
y_hat = model.predict(x)
print ("R^2:", metrics.r2_score(y_hat, y))
# Out:
# R^2: 0.5324295166208215

# %%
#Arab World Regression
from sklearn.linear_model import LinearRegression

est = LinearRegression(fit_intercept = True)

x = df_aw[['Unemployment, total (% of total labor force)']]
y = df_aw[['Suicide mortality rate (per 100,000 population)']]

est.fit(x, y)

print("Coefficients:", est.coef_)
print ("Intercept:", est.intercept_)
# Out:
# Coefficients: [[0.01927034]]
# Intercept: [4.21051987]

# %%
#Arab World R square
from sklearn import metrics

x = df_aw[['Unemployment, total (% of total labor force)']]
y = df_aw[['Suicide mortality rate (per 100,000 population)']]
model = LinearRegression()
model.fit(x, y)
y_hat = model.predict(x)
print ("R^2:", metrics.r2_score(y_hat, y))
# Out:
# R^2: -60.08242797069139

# %%
#Caribbean small states Regression
from sklearn.linear_model import LinearRegression

est = LinearRegression(fit_intercept = True)

x = df_css[['Unemployment, total (% of total labor force)']]
y = df_css[['Suicide mortality rate (per 100,000 population)']]

est.fit(x, y)

print("Coefficients:", est.coef_)
print ("Intercept:", est.intercept_)
# Out:
# Coefficients: [[0.09527102]]
# Intercept: [8.53379859]

# %%
#Caribbean small states R Square
from sklearn import metrics

x = df_css[['Unemployment, total (% of total labor force)']]
y = df_css[['Suicide mortality rate (per 100,000 population)']]
model = LinearRegression()
model.fit(x, y)
y_hat = model.predict(x)
print ("R^2:", metrics.r2_score(y_hat, y))
# Out:
# R^2: -5.791075603303788

# %%
#Central Europe and the Baltics Regression
from sklearn.linear_model import LinearRegression

est = LinearRegression(fit_intercept = True)

x = df_ceb[['Unemployment, total (% of total labor force)']]
y = df_ceb[['Suicide mortality rate (per 100,000 population)']]

est.fit(x, y)

print("Coefficients:", est.coef_)
print ("Intercept:", est.intercept_)
# Out:
# Coefficients: [[0.61636065]]
# Intercept: [11.05273556]

# %%
#Central Europe and the Baltics R Square
from sklearn import metrics

x = df_ceb[['Unemployment, total (% of total labor force)']]
y = df_ceb[['Suicide mortality rate (per 100,000 population)']]
model = LinearRegression()
model.fit(x, y)
y_hat = model.predict(x)
print ("R^2:", metrics.r2_score(y_hat, y))
# Out:
# R^2: 0.8043987752201747

# %%
#East Asia & Pacific Regression
from sklearn.linear_model import LinearRegression

est = LinearRegression(fit_intercept = True)

x = df_eap[['Unemployment, total (% of total labor force)']]
y = df_eap[['Suicide mortality rate (per 100,000 population)']]

est.fit(x, y)

print("Coefficients:", est.coef_)
print ("Intercept:", est.intercept_)
# Out:
# Coefficients: [[5.76937605]]
# Intercept: [-14.33667915]

# %%
#East Asia & Pacific R Square
from sklearn import metrics

x = df_eap[['Unemployment, total (% of total labor force)']]
y = df_eap[['Suicide mortality rate (per 100,000 population)']]
model = LinearRegression()
model.fit(x, y)
y_hat = model.predict(x)
print ("R^2:", metrics.r2_score(y_hat, y))
# Out:
# R^2: 0.8307416725740502

# %%
#Euro area Regression
from sklearn.linear_model import LinearRegression

est = LinearRegression(fit_intercept = True)

x = df_ea[['Unemployment, total (% of total labor force)']]
y = df_ea[['Suicide mortality rate (per 100,000 population)']]

est.fit(x, y)

print("Coefficients:", est.coef_)
print ("Intercept:", est.intercept_)
# Out:
# Coefficients: [[0.06385718]]
# Intercept: [11.80645155]

# %%
#Euro area R Square
from sklearn import metrics

x = df_ea[['Unemployment, total (% of total labor force)']]
y = df_ea[['Suicide mortality rate (per 100,000 population)']]
model = LinearRegression()
model.fit(x, y)
y_hat = model.predict(x)
print ("R^2:", metrics.r2_score(y_hat, y))
# Out:
# R^2: -64.10081725243866

# %%
#Europe & Central Asia Regression
from sklearn.linear_model import LinearRegression

est = LinearRegression(fit_intercept = True)

x = df_eca[['Unemployment, total (% of total labor force)']]
y = df_eca[['Suicide mortality rate (per 100,000 population)']]

est.fit(x, y)

print("Coefficients:", est.coef_)
print ("Intercept:", est.intercept_)
# Out:
# Coefficients: [[1.54674236]]
# Intercept: [3.98948201]

# %%
#Europe & Central Asia R Square
from sklearn import metrics

x = df_eca[['Unemployment, total (% of total labor force)']]
y = df_eca[['Suicide mortality rate (per 100,000 population)']]
model = LinearRegression()
model.fit(x, y)
y_hat = model.predict(x)
print ("R^2:", metrics.r2_score(y_hat, y))
# Out:
# R^2: -1.590768291545043

# %%
#European Union Regression
from sklearn.linear_model import LinearRegression

est = LinearRegression(fit_intercept = True)

x = df_eu[['Unemployment, total (% of total labor force)']]
y = df_eu[['Suicide mortality rate (per 100,000 population)']]

est.fit(x, y)

print("Coefficients:", est.coef_)
print ("Intercept:", est.intercept_)
# Out:
# Coefficients: [[0.38198762]]
# Intercept: [9.64923221]

# %%
#European Union R Square
from sklearn import metrics

x = df_eu[['Unemployment, total (% of total labor force)']]
y = df_eu[['Suicide mortality rate (per 100,000 population)']]
model = LinearRegression()
model.fit(x, y)
y_hat = model.predict(x)
print ("R^2:", metrics.r2_score(y_hat, y))
# Out:
# R^2: -1.2656654886696446

# %%
#Latin America & Caribbean Regression
from sklearn.linear_model import LinearRegression

est = LinearRegression(fit_intercept = True)

x = df_lac[['Unemployment, total (% of total labor force)']]
y = df_lac[['Suicide mortality rate (per 100,000 population)']]

est.fit(x, y)

print("Coefficients:", est.coef_)
print ("Intercept:", est.intercept_)
# Out:
# Coefficients: [[-0.02516456]]
# Intercept: [5.99623518]

# %%
#Latin America & Caribbean R Square
from sklearn import metrics

x = df_lac[['Unemployment, total (% of total labor force)']]
y = df_lac[['Suicide mortality rate (per 100,000 population)']]
model = LinearRegression()
model.fit(x, y)
y_hat = model.predict(x)
print ("R^2:", metrics.r2_score(y_hat, y))
# Out:
# R^2: -169.77176474398414

# %%
#Middle East & North Africa Regression
from sklearn.linear_model import LinearRegression

est = LinearRegression(fit_intercept = True)

x = df_mena[['Unemployment, total (% of total labor force)']]
y = df_mena[['Suicide mortality rate (per 100,000 population)']]

est.fit(x, y)

print("Coefficients:", est.coef_)
print ("Intercept:", est.intercept_)
# Out:
# Coefficients: [[0.13495066]]
# Intercept: [3.36684422]

# %%
#Middle East & North Africa R Square
from sklearn import metrics

x = df_mena[['Unemployment, total (% of total labor force)']]
y = df_mena[['Suicide mortality rate (per 100,000 population)']]
model = LinearRegression()
model.fit(x, y)
y_hat = model.predict(x)
print ("R^2:", metrics.r2_score(y_hat, y))
# Out:
# R^2: -1.5389509047186731

# %%
#Pacific island small states Regression
from sklearn.linear_model import LinearRegression

est = LinearRegression(fit_intercept = True)

x = df_pss[['Unemployment, total (% of total labor force)']]
y = df_pss[['Suicide mortality rate (per 100,000 population)']]

est.fit(x, y)

print("Coefficients:", est.coef_)
print ("Intercept:", est.intercept_)
# Out:
# Coefficients: [[0.24324379]]
# Intercept: [13.03817087]

# %%
#Pacific island small states R Square
from sklearn import metrics

x = df_pss[['Unemployment, total (% of total labor force)']]
y = df_pss[['Suicide mortality rate (per 100,000 population)']]
model = LinearRegression()
model.fit(x, y)
y_hat = model.predict(x)
print ("R^2:", metrics.r2_score(y_hat, y))
# Out:
# R^2: -101.88995160897905

# %%
#Sub-Saharan Africa Regression
from sklearn.linear_model import LinearRegression

est = LinearRegression(fit_intercept = True)

x = df_ssa[['Unemployment, total (% of total labor force)']]
y = df_ssa[['Suicide mortality rate (per 100,000 population)']]

est.fit(x, y)

print("Coefficients:", est.coef_)
print ("Intercept:", est.intercept_)
# Out:
# Coefficients: [[-0.05246858]]
# Intercept: [8.30730961]

# %%
#Sub-Saharan Africa R Square
from sklearn import metrics

x = df_ssa[['Unemployment, total (% of total labor force)']]
y = df_ssa[['Suicide mortality rate (per 100,000 population)']]
model = LinearRegression()
model.fit(x, y)
y_hat = model.predict(x)
print ("R^2:", metrics.r2_score(y_hat, y))
# Out:
# R^2: -1124.468630606404
